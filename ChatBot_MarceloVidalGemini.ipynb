# %% [markdown]
# <a href="https://colab.research.google.com/github/marceloprog/ImersaoIAGemini/blob/main/ChatBot_MarceloVidalGemini.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from typing import TextIO
"""
At the command line, only need to run once to install the package via pip:

$ pip install google-generativeai
"""

import google.generativeai as genai
from google.colab import userdata
api_key = userdata.get('SECRET_KEY')
genai.configure(api_key=api_key)

# Set up the model
generation_config = {
  "temperature": 1,
}

safety_settings = [
  {
    "category": "HARM_CATEGORY_HARASSMENT",
    "threshold": "BLOCK_MEDIUM_AND_ABOVE"
  },
  {
    "category": "HARM_CATEGORY_HATE_SPEECH",
    "threshold": "BLOCK_MEDIUM_AND_ABOVE"
  },
  {
    "category": "HARM_CATEGORY_SEXUALLY_EXPLICIT",
    "threshold": "BLOCK_MEDIUM_AND_ABOVE"
  },
  {
    "category": "HARM_CATEGORY_DANGEROUS_CONTENT",
    "threshold": "BLOCK_MEDIUM_AND_ABOVE"
  },
]

model = genai.GenerativeModel(model_name="gemini-1.5-pro-latest",
                              generation_config=generation_config,
                              safety_settings=safety_settings)
confirma="N"
while True:

 print(" *** ChatBot (Gemini - Google)para dica de presentes *** ")
 print(" ***         Projeto Imersão Alura / 2024            *** ")
 print(" ***         Autor (Marcelo Vidal) v.1.0             *** ")
 print(" ******************************************************* ")
 print(' Preencha os campos abaixo com os dados da pessoa a ser presenteada')
 print(' Observação : o preenchimento dos campos não é obrigatório, porém quanto mais dados forem informados melhor será a resposta')
 print("     ");

 idade = input("1 - Idade da pessoa a ser presenteada : ")
 sexo = input("2 - Sexo por extenso : ")
 religiao = input("3 - Religião : ")
 relacao = input("4 - Qual seu tipo de relação com essa pessoa (é sua Mãe, Conjuge, Chefe, Amigo, Cunhado...) : ")
 datacomemorativa = input("5 - Se for para alguma data comemorativa descreva qual é a data ( Aniversário, casamento, dia das mães...) : ")
 hobby = input ("6 - O que a pessoa gosta de fazer / hobby (importante preencher esse campo) : ")
 trabalho = input("7 - Informações referente ao trabalho da pessoa : ")
 estilo = input("8 - Estilo da pessoa (extrovertida , tímida, séria.. ), pode ter vários esilos : ")
 valorminimo = input("9 - Valor mínimo para o presente (não coloque o simbolo R$) (ex: 80) : ")
 valormaximo = input("10 - Valor máximo do presente (não coloque o simbolo R$) (ex:1000) : ")
 naoquer = input("11-  Descreva algo que a pessoa não gosta e/ou que não deve ser sugerido como presente. : ")
 informacao =  input("12 - Alguma outra informação que julgar importante (ex: tipo físico, etinia, o que a pessoa não gosta..) : ")

 confirma=input("Confirma parametros informados ? Tecle(S=Sim , N=Não) : ")
 confirma=confirma.upper()
 if confirma!="S":
  continue
 if confirma=="S":
   break

print("Aguarde um momento estamos trabalhando .......")
texto_pesquisa=""

if len(relacao)>0 :
  texto_pesquisa = texto_pesquisa+" para um(a)  "+relacao

if len(idade)>0 :
  texto_pesquisa = texto_pesquisa+" com idade de "+idade+" anos"

if len(sexo)>0 :
  texto_pesquisa = texto_pesquisa+", do sexo "+sexo

if len(religiao)>0 :
  texto_pesquisa = texto_pesquisa+", da religião  "+religiao

if len(datacomemorativa)>0 :
  texto_pesquisa = texto_pesquisa+" para comemorar o(a) "+datacomemorativa

if len(hobby)>0 :
  texto_pesquisa = texto_pesquisa+", e a pessoa gosta de ("+hobby+")"

if len(trabalho)>0 :
  texto_pesquisa = texto_pesquisa+", e trabalha com  ("+trabalho+")"

if len(estilo)>0 :
  texto_pesquisa = texto_pesquisa+", tem um estilo estilo ("+estilo+")."

if len(valorminimo)>0 :
  texto_pesquisa = texto_pesquisa+" O presente deve ter o valor maior que R$ "+valorminimo+"."

if len(valormaximo)>0 :
  texto_pesquisa = texto_pesquisa+" O presente deve ter o valor menor que R$ "+valormaximo+"."

if len(informacao)>0 :
  texto_pesquisa = texto_pesquisa+" Informações sobre o presente "+informacao+"."

if len(naoquer)>0 :
  texto_pesquisa = texto_pesquisa+" É importante que o presente não seja um desses a seguir ("+naoquer+")."

texto_pesquisa="Me de dicas de presente "+texto_pesquisa+" Quero imagens do presente e dicas de onde posso compra-lo."

convo = model.start_chat(history=[])

print("* Conteúdo do request *")
print(texto_pesquisa)
print(" * ")

convo.send_message(texto_pesquisa)
print(convo.last.text)
# Out:
#  *** ChatBot (Gemini - Google)para dica de presentes ***
#  ***         Projeto Imersão Alura / 2024            ***
#  ***         Autor (Marcelo Vidal) v.1.0             ***
#  *******************************************************
#  Preencha os campos abaixo com os dados da pessoa a ser presenteada
#  Observação : o preenchimento dos campos não é obrigatório, porém quanto mais dados forem informados melhor será a resposta
#
# 1 - Idade da pessoa a ser presenteada : 40
# 2 - Sexo por extenso : FEMININO
# 3 - Religião : CATÓLICA
# 4 - Qual seu tipo de relação com essa pessoa (é sua Mãe, Conjuge, Chefe, Amigo, Cunhado...) : ALEGRE
# 5 - Se for para alguma data comemorativa descreva qual é a data ( Aniversário, casamento, dia das mães...) : aniversário
# 6 - O que a pessoa gosta de fazer / hobby (importante preencher esse campo) : churrasco
# 7 - Informações referente ao trabalho da pessoa :
# ...
